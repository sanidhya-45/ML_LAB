# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
# df= pd.read_csv("advertising.csv")
print(df.head())
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df= pd.read_csv("adver.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
graphsheet =plt.figure(figsize=(20, 20))
graphsheet.add_subplot(3,3,1)
plt.scatter(df['TV'], df['Sales'])
plt.xlabel("Money spent on TV")
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
graphsheet =plt.figure(figsize=(20, 20))
graphsheet.add_subplot(3,3,1)
plt.scatter(df['Radio'], df['Sales'], c='green')
plt.xlabel("Money spent on TV")
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
graphsheet =plt.figure(figsize=(20, 20))
graphsheet.add_subplot(3,3,1)
plt.scatter(df['Newspaper'], df['Sales'], c='orange')
plt.xlabel("Money spent on TV")
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
def linReg(x, y):
    print(x + " vs " + y)
    print()
    
    x_train, x_test, y_train, y_test = train_test_split(df[x], df[y], test_size= 0.3)
    x_train= x_train.to_numpy().reshape(-1,1)
    x_test= x_test.to_numpy().reshape(-1,1)
    y_train= y_train.to_numpy().reshape(-1,1)
    y_test= y_test.to_numpy().reshape(-1,1)
    
#     print(x_train)
    
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    
    print("Coeff=", lr.coef_[0][0], "\nIntercept=", lr.intercept_[0])
    pred= lr.predict(x_test)
    
#     print("the linear model of {} versus {} is Y= {:.3} + {:.2}X", format (x,y, lr.intercept_[0], lr.coef_[0][0]))
    print("The linear model of {} versus {} is: Y = {:.3} + {:.2}X".format(x, y, lr.intercept_[0], lr.coef_[0][0]))

    # this {:.3} means upto 3 decimal places and {:.2} upto two decimal places
    
    # root mean squared error
    rmse= np.sqrt(mean_squared_error(y_test, pred))
    
    # mean absolute error
    mae= mean_absolute_error(y_test, pred)
    
    #mean squared error
    mse= mean_squared_error(y_test, pred)
    print("Root Mean Square Srror= {}\nMean Absolute Error = {}\nMean Squared Error = {}".format(rmse,mae,mse))
    
    #Plotting the final Graph
    
    plt.scatter(x_train,y_train)
    plt.scatter(x_test,y_test)
    plt.xlabel("Money Spent on "+x)
    plt.ylabel(y)
    plt.title(x+" vs "+y)
    plt.plot(x_test,pred,c='black')

# %%
linReg('TV', 'Sales')
# Out:
# TV vs Sales
#
# Coeff= 0.04422871468372561
# Intercept= 7.178095416826439
# The linear model of TV versus Sales is: Y = 7.18 + 0.044X
# Root Mean Square Srror= 3.361300614170542
# Mean Absolute Error = 2.571708252662853
# Mean Squared Error = 11.298341818823262

# %%
linReg('Radio', 'Sales')
# Out:
# Radio vs Sales
#
# Coeff= 0.18665804313309428
# Intercept= 9.378423672715982
# The linear model of Radio versus Sales is: Y = 9.38 + 0.19X
# Root Mean Square Srror= 4.356451988755052
# Mean Absolute Error = 3.5615346777538983
# Mean Squared Error = 18.978673930327844

# %%
linReg('Newspaper', 'Sales')
# Out:
# Newspaper vs Sales
#
# Coeff= 0.05168901266309226
# Intercept= 12.524982383854883
# The linear model of Newspaper versus Sales is: Y = 12.5 + 0.052X
# Root Mean Square Srror= 4.255308766070607
# Mean Absolute Error = 3.455849811221905
# Mean Squared Error = 18.107652694597355
